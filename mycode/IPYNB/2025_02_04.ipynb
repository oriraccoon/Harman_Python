# %% [markdown]
# # Python
# - 변수

# %%
num = 3 # 최초 할당(초기화)

# %%
print(num)
# Out:
# 3

# %% [markdown]
# ![image.png](attachment:c909a843-de30-4a94-adf7-c96acac992ef.png)

# %%
num1 = 2

# %%
num2 = 4

# %%
num2 = 20

# %%
num3 = 3.141592

# %%
num4 = -1.25

# %%
num5 = 3.0

# %%
print(num1, num2, num3, num4, num5)
# Out:
# 2 20 3.141592 -1.25 3.0

# %% [markdown]
# ![image.png](attachment:2112c4ce-5278-44d4-92a5-c1ccf261594c.png)

# %%
str1 = "Hello World!"

# %%
str2 = 'Hi Python'

# %%
bool1 = True

# %%
bool2 = False

# %%
print(str1, str2, bool1, bool2)
# Out:
# Hello World! Hi Python True False

# %%
나이 = 20
print(나이) # 한글 가능은 함
# Out:
# 20

# %%
from keyword import kwlist
print(kwlist)
# Out:
# ['False', 'None', 'True', '__peg_parser__', 'and', 'as', 'assert', 'async', 'await', 'break', 'class', 'continue', 'def', 'del', 'elif', 'else', 'except', 'finally', 'for', 'from', 'global', 'if', 'import', 'in', 'is', 'lambda', 'nonlocal', 'not', 'or', 'pass', 'raise', 'return', 'try', 'while', 'with', 'yield']

# %%
num1 = 20
num2 = 3
print(num1 + num2)
print(num1 - num2)
print(num1 * num2)
print(num1 / num2)
print(num1 // num2)
print(num1 % num2)
# Out:
# 23
# 17
# 60
# 6.666666666666667
# 6
# 2

# %%
print(2**8)
# Out:
# 256

# %%
age = 25

# age에 한 살을 추가
age += 1

print(age)
# Out:
# 26

# %%
money *= 2
print(money)
# Out:
# 4000

# %%
money = 1000

# money를 2배 한 값을 다시 대입 후 출력
money *= 2

print(money)
# Out:
# 2000

# %%
print(10 < 5)
print(10 <= 10)
# Out:
# False
# True

# %%
is_hot = False
print(not is_hot)
# Out:
# True

# %%
is_hot = False
# if is_hot is True, make False
# else, make True
is_hot = not is_hot
print(is_hot)
# Out:
# True
